# %%
import requests
import pandas as pd
import plotly.express as px

# Define the World Bank API endpoint
def fetch_world_bank_data(indicator, date):
    url = f"http://api.worldbank.org/v2/country/all/indicator/{indicator}?date={date}&format=json&per_page=300"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if len(data) > 1:
            return pd.DataFrame(data[1])
        else:
            print("No data available for the specified indicator and date.")
            return pd.DataFrame()
    else:
        print(f"Failed to fetch data from World Bank API: {response.status_code}")
        return pd.DataFrame()

# Fetch data for a specific indicator and year
indicator = "SH.H2O.BASW.ZS"  # Water
year = "2021"  # Year of interest
data = fetch_world_bank_data(indicator, year)

# Filter and clean the data
if not data.empty:
    data = data[["countryiso3code", "country", "value"]]
    data = data.dropna()  # Remove rows with missing values
    data = data.rename(columns={"countryiso3code": "iso_alpha", "value": "GDP"})
    data["GDP"] = data["GDP"].astype(float)  # Ensure GDP is numeric
    data = data.sort_values(by="GDP", ascending=False)

# Create a choropleth map
if not data.empty:
    fig = px.choropleth(
        data,
        locations="iso_alpha",
        color="GDP",
        hover_name="country",
        color_continuous_scale="Viridis",
        title=f"World Ranking by GDP ({year})",
        labels={"GDP": "GDP (Current US$)"}
    )

    fig.update_layout(
        geo=dict(showframe=False, showcoastlines=False, projection_type="equirectangular"),
        coloraxis_colorbar=dict(title="GDP (US$)")
    )

    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f5184daa-5bb0-4631-8167-771cd16cd567" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5184daa-5bb0-4631-8167-771cd16cd567")) {                    Plotly.newPlot(                        "f5184daa-5bb0-4631-8167-771cd16cd567",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eiso_alpha=%{location}\u003cbr\u003eGDP (Current US$)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":[{"id":"HK","value":"Hong Kong SAR, China"},{"id":"MO","value":"Macao SAR, China"},{"id":"KW","value":"Kuwait"},{"id":"AE","value":"United Arab Emirates"},{"id":"IL","value":"Israel"},{"id":"CL","value":"Chile"},{"id":"PR","value":"Puerto Rico"},{"id":"GL","value":"Greenland"},{"id":"AD","value":"Andorra"},{"id":"GI","value":"Gibraltar"},{"id":"AT","value":"Austria"},{"id":"DE","value":"Germany"},{"id":"PF","value":"French Polynesia"},{"id":"FR","value":"France"},{"id":"BE","value":"Belgium"},{"id":"FI","value":"Finland"},{"id":"FO","value":"Faroe Islands"},{"id":"SM","value":"San Marino"},{"id":"SG","value":"Singapore"},{"id":"LI","value":"Liechtenstein"},{"id":"IS","value":"Iceland"},{"id":"MU","value":"Mauritius"},{"id":"NL","value":"Netherlands"},{"id":"NO","value":"Norway"},{"id":"MP","value":"Northern Mariana Islands"},{"id":"MC","value":"Monaco"},{"id":"CH","value":"Switzerland"},{"id":"DK","value":"Denmark"},{"id":"TM","value":"Turkmenistan"},{"id":"EE","value":"Estonia"},{"id":"MT","value":"Malta"},{"id":"HU","value":"Hungary"},{"id":"GB","value":"United Kingdom"},{"id":"TH","value":"Thailand"},{"id":"RO","value":"Romania"},{"id":"NZ","value":"New Zealand"},{"id":"GR","value":"Greece"},{"id":"QA","value":"Qatar"},{"id":"AU","value":"Australia"},{"id":"AM","value":"Armenia"},{"id":"KR","value":"Korea, Rep."},{"id":"MF","value":"St. Martin (French part)"},{"id":"ES","value":"Spain"},{"id":"BH","value":"Bahrain"},{"id":"IT","value":"Italy"},{"id":"BM","value":"Bermuda"},{"id":"BN","value":"Brunei Darussalam"},{"id":"US","value":"United States"},{"id":"LY","value":"Libya"},{"id":"LU","value":"Luxembourg"},{"id":"CZ","value":"Czechia"},{"id":"VG","value":"British Virgin Islands"},{"id":"XC","value":"Euro area"},{"id":"XU","value":"North America"},{"id":"CR","value":"Costa Rica"},{"id":"SK","value":"Slovak Republic"},{"id":"CY","value":"Cyprus"},{"id":"IM","value":"Isle of Man"},{"id":"SE","value":"Sweden"},{"id":"GU","value":"Guam"},{"id":"PY","value":"Paraguay"},{"id":"BR","value":"Brazil"},{"id":"PW","value":"Palau"},{"id":"MV","value":"Maldives"},{"id":"MX","value":"Mexico"},{"id":"NC","value":"New Caledonia"},{"id":"UY","value":"Uruguay"},{"id":"SI","value":"Slovenia"},{"id":"V4","value":"Post-demographic dividend"},{"id":"OE","value":"OECD members"},{"id":"PT","value":"Portugal"},{"id":"AS","value":"American Samoa"},{"id":"TV","value":"Tuvalu"},{"id":"CA","value":"Canada"},{"id":"BY","value":"Belarus"},{"id":"XD","value":"High income"},{"id":"JP","value":"Japan"},{"id":"BT","value":"Bhutan"},{"id":"BG","value":"Bulgaria"},{"id":"EU","value":"European Union"},{"id":"JO","value":"Jordan"},{"id":"TT","value":"Trinidad and Tobago"},{"id":"ME","value":"Montenegro"},{"id":"LV","value":"Latvia"},{"id":"TC","value":"Turks and Caicos Islands"},{"id":"TO","value":"Tonga"},{"id":"EG","value":"Egypt, Arab Rep."},{"id":"SA","value":"Saudi Arabia"},{"id":"BB","value":"Barbados"},{"id":"BZ","value":"Belize"},{"id":"IQ","value":"Iraq"},{"id":"AG","value":"Antigua and Barbuda"},{"id":"WS","value":"Samoa"},{"id":"SV","value":"El Salvador"},{"id":"PS","value":"West Bank and Gaza"},{"id":"BD","value":"Bangladesh"},{"id":"LT","value":"Lithuania"},{"id": ...

# %%
import requests
import pandas as pd
import plotly.express as px

# Define the World Bank API endpoint
def fetch_world_bank_data(indicator, date):
    url = f"http://api.worldbank.org/v2/country/all/indicator/{indicator}?date={date}&format=json&per_page=300"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if len(data) > 1:
            return pd.DataFrame(data[1])
        else:
            print("No data available for the specified indicator and date.")
            return pd.DataFrame()
    else:
        print(f"Failed to fetch data from World Bank API: {response.status_code}")
        return pd.DataFrame()

# Fetch data for a specific indicator and year
indicator = "SI.POV.GINI"  # GINI Coefficient
year = "2021"  # Year of interest
data = fetch_world_bank_data(indicator, year)

# Filter and clean the data
if not data.empty:
    data = data[["countryiso3code", "country", "value"]]
    data = data.dropna()  # Remove rows with missing values
    data = data.rename(columns={"countryiso3code": "iso_alpha", "value": "GDP"})
    data["GDP"] = data["GDP"].astype(float)  # Ensure GDP is numeric
    data = data.sort_values(by="GDP", ascending=False)

# Create a choropleth map
if not data.empty:
    fig = px.choropleth(
        data,
        locations="iso_alpha",
        color="GDP",
        hover_name="country",
        color_continuous_scale="Viridis",
        title=f"World Ranking by GDP ({year})",
        labels={"GDP": "GDP (Current US$)"}
    )

    fig.update_layout(
        geo=dict(showframe=False, showcoastlines=False, projection_type="equirectangular"),
        coloraxis_colorbar=dict(title="GDP (US$)")
    )

    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3e77f917-ef31-4933-8968-8f200452a16c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e77f917-ef31-4933-8968-8f200452a16c")) {                    Plotly.newPlot(                        "3e77f917-ef31-4933-8968-8f200452a16c",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eiso_alpha=%{location}\u003cbr\u003eGDP (Current US$)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":[{"id":"CO","value":"Colombia"},{"id":"BR","value":"Brazil"},{"id":"PA","value":"Panama"},{"id":"CR","value":"Costa Rica"},{"id":"EC","value":"Ecuador"},{"id":"TR","value":"Turkiye"},{"id":"CF","value":"Central African Republic"},{"id":"PY","value":"Paraguay"},{"id":"AR","value":"Argentina"},{"id":"CM","value":"Cameroon"},{"id":"BO","value":"Bolivia"},{"id":"UY","value":"Uruguay"},{"id":"PH","value":"Philippines"},{"id":"MY","value":"Malaysia"},{"id":"JM","value":"Jamaica"},{"id":"PE","value":"Peru"},{"id":"US","value":"United States"},{"id":"BG","value":"Bulgaria"},{"id":"SV","value":"El Salvador"},{"id":"KE","value":"Kenya"},{"id":"DO","value":"Dominican Republic"},{"id":"IL","value":"Israel"},{"id":"TG","value":"Togo"},{"id":"BF","value":"Burkina Faso"},{"id":"LT","value":"Lithuania"},{"id":"SN","value":"Senegal"},{"id":"CN","value":"China"},{"id":"ML","value":"Mali"},{"id":"ID","value":"Indonesia"},{"id":"IR","value":"Iran, Islamic Rep."},{"id":"CI","value":"Cote d'Ivoire"},{"id":"RU","value":"Russian Federation"},{"id":"TH","value":"Thailand"},{"id":"IT","value":"Italy"},{"id":"PT","value":"Portugal"},{"id":"BJ","value":"Benin"},{"id":"LV","value":"Latvia"},{"id":"ME","value":"Montenegro"},{"id":"GE","value":"Georgia"},{"id":"RO","value":"Romania"},{"id":"ES","value":"Spain"},{"id":"TN","value":"Tunisia"},{"id":"GW","value":"Guinea-Bissau"},{"id":"RS","value":"Serbia"},{"id":"GR","value":"Greece"},{"id":"KR","value":"Korea, Rep."},{"id":"NE","value":"Niger"},{"id":"IN","value":"India"},{"id":"LU","value":"Luxembourg"},{"id":"GB","value":"United Kingdom"},{"id":"EE","value":"Estonia"},{"id":"FR","value":"France"},{"id":"CY","value":"Cyprus"},{"id":"AT","value":"Austria"},{"id":"IE","value":"Ireland"},{"id":"SE","value":"Sweden"},{"id":"HU","value":"Hungary"},{"id":"KZ","value":"Kazakhstan"},{"id":"HR","value":"Croatia"},{"id":"KG","value":"Kyrgyz Republic"},{"id":"PL","value":"Poland"},{"id":"DK","value":"Denmark"},{"id":"AM","value":"Armenia"},{"id":"FI","value":"Finland"},{"id":"TO","value":"Tonga"},{"id":"BE","value":"Belgium"},{"id":"CZ","value":"Czechia"},{"id":"NL","value":"Netherlands"},{"id":"MD","value":"Moldova"},{"id":"SI","value":"Slovenia"},{"id":"SK","value":"Slovak Republic"}],"locations":["COL","BRA","PAN","CRI","ECU","TUR","CAF","PRY","ARG","CMR","BOL","URY","PHL","MYS","JAM","PER","USA","BGR","SLV","KEN","DOM","ISR","TGO","BFA","LTU","SEN","CHN","MLI","IDN","IRN","CIV","RUS","THA","ITA","PRT","BEN","LVA","MNE","GEO","ROU","ESP","TUN","GNB","SRB","GRC","KOR","NER","IND","LUX","GBR","EST","FRA","CYP","AUT","IRL","SWE","HUN","KAZ","HRV","KGZ","POL","DNK","ARM","FIN","TON","BEL","CZE","NLD","MDA","SVN","SVK"],"name":"","z":[55.1,52.9,50.9,48.7,45.8,44.4,43.0,42.9,42.4,42.2,40.9,40.8,40.7,40.7,40.2,40.1,39.7,39.0,39.0,38.7,38.5,37.9,37.9,37.4,36.7,36.2,35.7,35.7,35.5,35.5,35.3,35.1,34.9,34.8,34.6,34.4,34.3,34.3,34.2,33.9,33.9,33.7,33.4,33.1,32.9,32.9,32.9,32.8,32.7,32.4,31.8,31.5,31.3,30.7,30.1,29.8,29.2,29.2,28.9,28.8,28.5,28.3,27.9,27.7,27.1,26.6,26.2,25.7,25.7,24.3,24.1],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks ...

# %%
#GB.XPD.RSDV.GD.ZS
import requests
import pandas as pd
import plotly.express as px

# Define the World Bank API endpoint
def fetch_world_bank_data(indicator, date):
    url = f"http://api.worldbank.org/v2/country/all/indicator/{indicator}?date={date}&format=json&per_page=300"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if len(data) > 1:
            return pd.DataFrame(data[1])
        else:
            print("No data available for the specified indicator and date.")
            return pd.DataFrame()
    else:
        print(f"Failed to fetch data from World Bank API: {response.status_code}")
        return pd.DataFrame()

# Fetch data for a specific indicator and year
indicator = "GB.XPD.RSDV.GD.ZS"  #
year = "2021"  # Year of interest
data = fetch_world_bank_data(indicator, year)

# Filter and clean the data
if not data.empty:
    data = data[["countryiso3code", "country", "value"]]
    data = data.dropna()  # Remove rows with missing values
    data = data.rename(columns={"countryiso3code": "iso_alpha", "value": "GDP"})
    data["GDP"] = data["GDP"].astype(float)  # Ensure GDP is numeric
    data = data.sort_values(by="GDP", ascending=False)

# Create a choropleth map
if not data.empty:
    fig = px.choropleth(
        data,
        locations="iso_alpha",
        color="GDP",
        hover_name="country",
        color_continuous_scale="Viridis",
        title=f"World Ranking by GDP ({year})",
        labels={"GDP": "GDP (Current US$)"}
    )

    fig.update_layout(
        geo=dict(showframe=False, showcoastlines=False, projection_type="equirectangular"),
        coloraxis_colorbar=dict(title="GDP (US$)")
    )

    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="74aa2db4-de86-42e9-af43-c8b7fc944e6a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74aa2db4-de86-42e9-af43-c8b7fc944e6a")) {                    Plotly.newPlot(                        "74aa2db4-de86-42e9-af43-c8b7fc944e6a",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eiso_alpha=%{location}\u003cbr\u003eGDP (Current US$)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":[{"id":"IL","value":"Israel"},{"id":"KR","value":"Korea, Rep."},{"id":"US","value":"United States"},{"id":"BE","value":"Belgium"},{"id":"SE","value":"Sweden"},{"id":"CH","value":"Switzerland"},{"id":"XU","value":"North America"},{"id":"JP","value":"Japan"},{"id":"AT","value":"Austria"},{"id":"DE","value":"Germany"},{"id":"V4","value":"Post-demographic dividend"},{"id":"FI","value":"Finland"},{"id":"OE","value":"OECD members"},{"id":"GB","value":"United Kingdom"},{"id":"XD","value":"High income"},{"id":"DK","value":"Denmark"},{"id":"IS","value":"Iceland"},{"id":"Z4","value":"East Asia & Pacific"},{"id":"1W","value":"World"},{"id":"CN","value":"China"},{"id":"T4","value":"East Asia & Pacific (IDA & IBRD countries)"},{"id":"4E","value":"East Asia & Pacific (excluding high income)"},{"id":"NL","value":"Netherlands"},{"id":"XC","value":"Euro area"},{"id":"EU","value":"European Union"},{"id":"FR","value":"France"},{"id":"Z7","value":"Europe & Central Asia"},{"id":"SI","value":"Slovenia"},{"id":"V3","value":"Late-demographic dividend"},{"id":"XT","value":"Upper middle income"},{"id":"CZ","value":"Czechia"},{"id":"XP","value":"Middle income"},{"id":"XO","value":"Low & middle income"},{"id":"NO","value":"Norway"},{"id":"XF","value":"IBRD only"},{"id":"ZT","value":"IDA & IBRD total"},{"id":"EE","value":"Estonia"},{"id":"CA","value":"Canada"},{"id":"PT","value":"Portugal"},{"id":"HU","value":"Hungary"},{"id":"ZQ","value":"Middle East & North Africa"},{"id":"AE","value":"United Arab Emirates"},{"id":"GR","value":"Greece"},{"id":"NZ","value":"New Zealand"},{"id":"IT","value":"Italy"},{"id":"PL","value":"Poland"},{"id":"ES","value":"Spain"},{"id":"TR","value":"Turkiye"},{"id":"B8","value":"Central Europe and the Baltics"},{"id":"HR","value":"Croatia"},{"id":"TH","value":"Thailand"},{"id":"IE","value":"Ireland"},{"id":"LT","value":"Lithuania"},{"id":"LU","value":"Luxembourg"},{"id":"RS","value":"Serbia"},{"id":"T7","value":"Europe & Central Asia (IDA & IBRD countries)"},{"id":"HK","value":"Hong Kong SAR, China"},{"id":"RU","value":"Russian Federation"},{"id":"SK","value":"Slovak Republic"},{"id":"EG","value":"Egypt, Arab Rep."},{"id":"7E","value":"Europe & Central Asia (excluding high income)"},{"id":"CY","value":"Cyprus"},{"id":"BG","value":"Bulgaria"},{"id":"LV","value":"Latvia"},{"id":"1A","value":"Arab World"},{"id":"QA","value":"Qatar"},{"id":"MT","value":"Malta"},{"id":"AR","value":"Argentina"},{"id":"RO","value":"Romania"},{"id":"BY","value":"Belarus"},{"id":"SA","value":"Saudi Arabia"},{"id":"VN","value":"Viet Nam"},{"id":"UY","value":"Uruguay"},{"id":"MO","value":"Macao SAR, China"},{"id":"MK","value":"North Macedonia"},{"id":"UA","value":"Ukraine"},{"id":"MU","value":"Mauritius"},{"id":"CU","value":"Cuba"},{"id":"OM","value":"Oman"},{"id":"MX","value":"Mexico"},{"id":"CR","value":"Costa Rica"},{"id":"GE","value":"Georgia"},{"id":"BF","value":"Burkina Faso"},{"id":"MD","value":"Moldova"},{"id":"AZ","value":"Azerbaijan"},{"id":"AM","value":"Armenia"},{"id":"BA","value":"Bosnia and Herzegovina"},{"id":"PA","value":"Panama"},{"id":"ML","value":"Mali"},{"id":"PK","value":"Pakistan"},{"id":"SV","value":"El Salvador"},{"id":"MM","value":"Myanmar"},{"id" ...
